# %% [markdown]
# ## Tuning best model with best optimizer
#
#
# Tune loss function:
#
#     1) relu
#
#     2) elu
#
#     3) linear
#
#     4) softplus
#
#     5) tanh
#
#     6) sigmoid
#
#
# #### A) Base model for activation function tuning: Feed Forward NN (Best model from optimizer tuning)
#
#   80% train / 20% test / 0% validation split
#
# **kernel_initializer:** glorot_normal
#
# **layers:** input(X columns), (X columns), output(1)
#
# **loss:** MSE
#
# **optimizer:** adamax

# %%
import tcc_utils
import tratamento_dados_empresa
from keras.initializers import glorot_normal as gl_normal, glorot_uniform as gl_uni, RandomUniform as rnd_uni

x_csv_path = './data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = './data/grendene-cotacao-raw.csv'

X = tratamento_dados_empresa.treat_economatica_indicadores_financeiros(x_csv_path)

# Spliting test / train and Feature Scaling
x_train, x_test, y_train, y_test, x_scaler, y_scaler = tratamento_dados_empresa. \
    get_scaled_splits_and_scaler(x_csv_path, y_csv_path, 0.2, 0)

number_hidden_layer = x_train.shape[1]
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 1) Relu
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'relu'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer]
activations = ['relu']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations, optimizer='adamax')
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
result_df = tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler, model_name='FF 3 | ReLU')
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# <IPython.core.display.Image object>
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 56)                3192
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 57
# =================================================================
# Total params: 3,249
# Trainable params: 3,249
# Non-trainable params: 0
# _________________________________________________________________
# None
#     Prediction      Real     % error
# 8     8.329129  8.491036    1.906796
# 0     7.485353  8.075241    7.304896
# 7     5.105690  5.156991    0.994778
# 9     5.455459  4.785659   13.995990
# 2     5.739205  4.616062   24.331184
# 1     4.713167  3.669486   28.442154
# 6     3.261162  3.491649    6.601083
# 3     3.648560  3.003443   21.479236
# 10    2.796643  1.377930  102.959695
# 5     0.979404  0.900556    8.755445
# 4     1.746615  0.667981  161.476697
# count     11.000000
# mean      34.386178
# std       50.897297
# min        0.994778
# 25%        6.952989
# 50%       13.995990
# 75%       26.386669
# max      161.476697
# Name: % error, dtype: float64
# Remove outliers from results and recalculate loss
#    Prediction      Real    % error
# 8    8.329129  8.491036   1.906796
# 0    7.485353  8.075241   7.304896
# 7    5.105690  5.156991   0.994778
# 9    5.455459  4.785659  13.995990
# 2    5.739205  4.616062  24.331184
# 1    4.713167  3.669486  28.442154
# 6    3.261162  3.491649   6.601083
# 3    3.648560  3.003443  21.479236
# 5    0.979404  0.900556   8.755445
# count     9.000000
# mean     12.645729
# std       9.982465
# min       0.994778
# 25%       6.601083
# 50%       8.755445
# 75%      21.479236
# max      28.442154
# Name: % error, dtype: float64
# MSE of training: 0.016528551382097332
# MSE of testing: 0.0999085009098053
# MSE of testing without first outliers: 0.06530699878931046

# %% [markdown]
# ### 2) Elu
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'elu'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer]
activations = ['elu']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations, optimizer='adamax')
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
result_df = tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler,
                          model_name='FF 3 | ELU', existing_df=result_df)
# Out:
# <IPython.core.display.Image object>
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 56)                3192
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 57
# =================================================================
# Total params: 3,249
# Trainable params: 3,249
# Non-trainable params: 0
# _________________________________________________________________
# None
#     Prediction      Real     % error
# 8     8.203557  8.491036    3.385676
# 0     7.886799  8.075241    2.333572
# 7     5.346985  5.156991    3.684207
# 9     4.555982  4.785659    4.799280
# 2     4.926751  4.616062    6.730604
# 1     5.279948  3.669486   43.887956
# 6     3.745707  3.491649    7.276164
# 3     3.355558  3.003443   11.723711
# 10    2.692198  1.377930   95.379833
# 5     0.074013  0.900556   91.781405
# 4     2.563573  0.667981  283.779312
# count     11.000000
# mean      50.432884
# std       85.022915
# min        2.333572
# 25%        4.241744
# 50%        7.276164
# 75%       67.834680
# max      283.779312
# Name: % error, dtype: float64
# Remove outliers from results and recalculate loss
#     Prediction      Real    % error
# 8     8.203557  8.491036   3.385676
# 0     7.886799  8.075241   2.333572
# 7     5.346985  5.156991   3.684207
# 9     4.555982  4.785659   4.799280
# 2     4.926751  4.616062   6.730604
# 1     5.279948  3.669486  43.887956
# 6     3.745707  3.491649   7.276164
# 3     3.355558  3.003443  11.723711
# 10    2.692198  1.377930  95.379833
# 5     0.074013  0.900556  91.781405
# count    10.000000
# mean     27.098241
# std      37.108473
# min       2.333572
# 25%       3.962976
# 50%       7.003384
# 75%      35.846895
# max      95.379833
# Name: % error, dtype: float64
# MSE of training: 0.04195641692389141
# MSE of testing: 0.1329999566078186
# MSE of testing without first outliers: 0.08846384286880493

# %% [markdown]
# ### 3) Linear
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>
# Name: % error, dtype: float64
# Remove outliers from results and recalculate loss
#     Prediction      Real    % error
# 8     7.123866  8.491036  16.101337
# 0     7.280993  8.075241   9.835594
# 7     6.193873  5.156991  20.106354
# 9     3.678519  4.785659  23.134533
# 2     3.816575  4.616062  17.319685
# 1     4.861408  3.669486  32.481985
# 6     3.649579  3.491649   4.523068
# 3     1.996682  3.003443  33.520248
# 10    1.208835  1.377930  12.271733
# count     9.000000
# mean     18.810504
# std       9.751025
# min       4.523068
# 25%      12.271733
# 50%      17.319685
# 75%      23.134533
# max      33.520248
# Name: % error, dtype: float64
# MSE of training: 0.024118583480065518
# MSE of testing: 0.15031114220619202
# MSE of testing without first outliers: 0.1417820155620575

# %% [markdown]
# ### 6) sigmoid
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'sigmoid'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer]
activations = ['sigmoid']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations, optimizer='adamax')
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
result_df = tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler,
                         model_name='FF 3 | Sigmoid', existing_df=result_df)
# Out:
# <IPython.core.display.Image object>
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 56)                3192
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 57
# =================================================================
# Total params: 3,249
# Trainable params: 3,249
# Non-trainable params: 0
# _________________________________________________________________
# None
#     Prediction      Real     % error
# 8     7.444606  8.491036   12.323934
# 0     7.342848  8.075241    9.069607
# 7     6.575038  5.156991   27.497574
# 9     4.243491  4.785659   11.329007
# 2     4.688572  4.616062    1.570812
# 1     4.539251  3.669486   23.702651
# 6     4.461507  3.491649   27.776502
# 3     2.551206  3.003443   15.057279
# 10    1.281874  1.377930    6.971099
# 5     0.702941  0.900556   21.943720
# 4     1.391476  0.667981  108.310737
# count     11.000000
# mean      24.141175
# std       29.209105
# min        1.570812
# 25%       10.199307
# 50%       15.057279
# 75%       25.600113
# max      108.310737
# Name: % error, dtype: float64
# Remove outliers from results and recalculate loss
#     Prediction      Real    % error
# 8     7.444606  8.491036  12.323934
# 0     7.342848  8.075241   9.069607
# 7     6.575038  5.156991  27.497574
# 9     4.243491  4.785659  11.329007
# 2     4.688572  4.616062   1.570812
# 1     4.539251  3.669486  23.702651
# 6     4.461507  3.491649  27.776502
# 3     2.551206  3.003443  15.057279
# 10    1.281874  1.377930   6.971099
# 5     0.702941  0.900556  21.943720
# count    10.000000
# mean     15.724219
# std       9.059995
# min       1.570812
# 25%       9.634457
# 50%      13.690606
# 75%      23.262919
# max      27.776502
# Name: % error, dtype: float64
# MSE of training: 0.03148038380525329
# MSE of testing: 0.09386462718248367
# MSE of testing without first outliers: 0.094825878739357

# %%
result_df.to_csv(r'results-activation-function.csv')

# %%
result_df.sort_values(by='Testing MSE after removing outlier')
# Out:
#         Model Name  Testing MSE  Testing MSE after removing outlier  \
# 3  FF 3 | Softplus     0.077642                            0.056636
# 0      FF 3 | ReLU     0.099909                            0.065307
# 2    FF 3 | Linear     0.146925                            0.076524
# 1       FF 3 | ELU     0.133000                            0.088464
# 5   FF 3 | Sigmoid     0.093865                            0.094826
# 4      FF 3 | Tanh     0.150311                            0.141782
#
#    Training MSE
# 3      0.034491
# 0      0.016529
# 2      0.065638
# 1      0.041956
# 5      0.031480
# 4      0.024119
